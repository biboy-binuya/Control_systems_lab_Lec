# %%
from openai import OpenAI

# Connect to LM Studio local server
client = OpenAI(
    base_url="http://127.0.0.1:1234/v1",
    api_key="lm-studio"  # any string works
)

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Enter to Continue || Type 'exit' or press ESC to exit): ")

    # Check for the ESC character (\x1b) OR a simple 'exit' command
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break
    print("User Input: " + query)
    print('- ' * 50)
    if not query.strip():
        continue
    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        # LangChain uses 'human' for user and 'ai' for assistant
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Ensured stream is called only once with the correctly mapped history
    stream = client.chat.completions.create(
        model="qwen/qwen3-4b-2507",
        messages=messages_with_history,
        stream=True
    )
    full_ai_response = ""       # Temporary variable to capture the full AI response for memory

    for chunk in stream:
        if chunk.choices[0].delta.content:
            content = chunk.choices[0].delta.content
            print(content, end="", flush=True)
            full_ai_response += content     # Build the string as it streams

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)
    print('\n ')     # Print a newline for readability
    print('=' * 100)
    print(' ')
# Out:
# User Input: Hi, my name is harvey
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hi Harvey! 👋 How can I assist you today? 😊
#
# ====================================================================================================
#
# User Input: Can you give me 2 commonly used microcontroller
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hi Harvey! 😊
#
# Sure! Here are two of the most commonly used microcontrollers:
#
# 1. **Arduino Uno**
#    - Based on the ATmega328P microcontroller
#    - Widely used in hobbyist projects, education, and prototyping
#    - Easy to program using Arduino IDE and has a large community of support
#    - Great for beginners due to its simplicity and extensive documentation
#
# 2. **STM32 (e.g., STM32F103C8T6)**
#    - A family of 32-bit ARM Cortex-M microcontrollers from STMicroelectronics
#    - Used in industrial, automotive, and IoT applications
#    - Offers high performance, low power consumption, and advanced features like timers and communication interfaces
#    - Popular in more advanced or professional embedded systems
#
# Both are very popular, but they serve different purposes — Arduino Uno for learning and simple projects, and STM32 for more complex, real-world applications.
#
# Let me know if you'd like help choosing one for a specific project! 🚀
#
# ====================================================================================================
#
# User Input: What is my name?
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Your name is **Harvey**! 😊
# It's a great name — strong, friendly, and full of character. (And I'm glad you're here!)
#
# How can I help you today, Harvey? 🚀💡
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
